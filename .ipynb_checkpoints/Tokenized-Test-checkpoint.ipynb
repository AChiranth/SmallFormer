# %%
import numpy as np

# %%
arr = np.load("texts/tokenized/tokens.npy")

# %%
arr[:10]
# Out:
# array([ 109,  119,  308, 1887, 3398, 7584, 4545, 3233, 5353, 2372],
#       dtype=int32)

# %%
offsets = np.load("texts/tokenized/doc_offsets.npy")

# %%
offsets
# Out:
# array([      0,  797409, 1206195, 1352159, 1379663, 1602644, 2313195,
#        2486884, 2733108, 3229544, 3590386, 4382464, 4619320, 5440506,
#        6053157, 6800435, 7382654, 8160137, 8915575, 9681430, 9992134])

# %%
vals, counts = np.unique(arr, return_counts=True)

# %%
vals
# Out:
# array([   0,    1,    2, ..., 8000, 8001, 8002], dtype=int32)

# %%
counts
# Out:
# array([     1,      1,      1, ..., 201826, 228450, 289928])
